# %% [markdown]
# # Week 3

# %% [markdown]
# ##### Assignment 1: Redesign a bad/misleading chart
#
# <img src="bad_chart_1.png">

# %%
import matplotlib.pyplot as plt

labels = '38%', '', ''
sizes = [38, 23, 69]
explode = (0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, 
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# > 38% of domain owners have put moderate to high consideration to how much their domains are worth

# %%
labels = '', '23%', ''
sizes = [38, 23, 69]
explode = (0, 0.1, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, 
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# > 23% of respondents have bought and sold domain names for a profit

# %%
labels = '', '', '69%'
sizes = [38, 23, 69]
explode = (0, 0, 0.1)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, 
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# > 69% of small business owners want to make time to enhance or update their online presence

# %% [markdown]
# ##### Assignment 2: Redesign your own charts

# %% [markdown]
# > See assignments week 2 for this one. I already redesigned my charts there.
#
# After receiving feedback from my teacher, I've further improved them.
#
# .

# %% [markdown]
# ##### Assignment 3: What is your headline? What is your story?

# %% [markdown]
# ##### Assignment 4: Group poster

# %% [markdown]
# <img src="Poster.png">
